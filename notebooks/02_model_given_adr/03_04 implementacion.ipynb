# %%
# load the models
import joblib
import pandas as pd

# %%
# load the models
models = joblib.load("models/catboost_multilabel_soc_models.joblib")

# %%
# load feature names and soc names
feature_names = pd.read_csv("notebooks/03_canada/feature_names.csv").squeeze().tolist()
soc_names = pd.read_csv("notebooks/03_canada/soc_columns.csv").squeeze().tolist()

# %%
# get predictions for a new report
def predict_soc(report):
    report_features = report[feature_names]
    soc_probs = {}
    for soc, model in models.items():
        prob = model.predict_proba(report_features)[:, 1][0]
        soc_probs[soc] = prob
    return soc_probs

# %%
# create an example with all features set to 0
example = pd.DataFrame(0, index=[0], columns=feature_names)

# Set specific values
example.loc[0, 'AGE_Y'] = 28
example.loc[0, 'GENDER_CODE'] = 1
example.loc[0, 'cefalexin'] = 1
example.loc[0, 'WEIGHT_KG'] = 89
example.loc[0, 'HEIGHT_CM'] = 175

# view the example
example
# Out:
#    AGE_Y  WEIGHT_KG  HEIGHT_CM  GENDER_CODE  furosemide  chlorpromazine  \
# 0     28         89        175            1           0               0
#
#    cephalothin  chlordiazepoxide hydrochloride  fursemide  \
# 0            0                               0          0
#
#    hydralazine hydrochloride  ...  prunus cerasus extract  \
# 0                          0  ...                       0
#
#    prunus cerasus root  prunus cerasus bark  cilgavimab  tixagevimab  \
# 0                    0                    0           0            0
#
#    daratumumab (humax-cd38)  sigvotatug vedotin  cephalosporin nos  \
# 0                         0                   0                  0
#
#    ravulizumab  NaN
# 0            0    0
#
# [1 rows x 9093 columns]

# %%
soc_probs = predict_soc(example)
soc_probs
# Out:
# {'Blood and lymphatic system disorders': np.float64(0.34913155260257706),
#  'Cardiac disorders': np.float64(0.3965561095327395),
#  'Congenital, familial and genetic disorders': np.float64(0.48681458572786696),
#  'Ear and labyrinth disorders': np.float64(0.4471424278427956),
#  'Endocrine disorders': np.float64(0.4323504219626227),
#  'Eye disorders': np.float64(0.4346611118725338),
#  'Gastrointestinal disorders': np.float64(0.4679180280551441),
#  'General disorders and administration site conditions': np.float64(0.5035631762232313),
#  'Hepatobiliary disorders': np.float64(0.42057607790586443),
#  'Immune system disorders': np.float64(0.4589830218372652),
#  'Infections and infestations': np.float64(0.37383084067046496),
#  'Injury, poisoning and procedural complications': np.float64(0.42655589255835585),
#  'Investigations': np.float64(0.39655420235358735),
#  'Metabolism and nutrition disorders': np.float64(0.32969266011469855),
#  'Musculoskeletal and connective tissue disorders': np.float64(0.41407191814209526),
#  'Neoplasms benign, malignant and unspecified (incl cysts and polyps)': np.float64(0.17394825406484626),
#  'Nervous system disorders': np.float64(0.4711320195898459),
#  'Pregnancy, puerperium and perinatal conditions': np.float64(0.1178647033256152),
#  'Product issues': np.float64(0.4938520846951434),
#  'Psychiatric disorders': np.float64(0.41272478916088273),
#  'Renal and urinary disorders': np.float64(0.35349987499734153),
#  'Reproductive system and breast disorders': np.float64(0.6417716066488385),
#  'Respiratory, thoracic and mediastinal disorders': np.float64(0.3983871239814926),
#  'Skin and subcutaneous tissue disorders': np.float64(0.49033406575594446),
#  'Social circumstances': np.float64(0.20356032787267714),
#  'Surgical and medical procedures': np.float64(0.42999174914792543),
#  'Vascular disorders': np.float64(0.43242138807711017)}
